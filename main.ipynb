# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/Trending-Youtube-Videos/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # import pandas library

# %%
df = pd.read_excel('/content/drive/MyDrive/Projects/Trending Youtube Videos/data/Lab-YoutubeTrendingVideos.xlsx')
df.head()
# Out:
#   🧪 Lab | YouTube Trending Videos
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
